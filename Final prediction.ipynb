# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm

DATADIR = "C:/Users/nx1766/Desktop/Test31"

# %%
import glob
filelist = glob.glob('C:/Users/nx1766/Desktop/Test31/*.jpg')

# %%
filelist
# Out:
# ['C:/Users/nx1766/Desktop/Test31\\0022303c-2d92-4f5a-8251-dbe878161100.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\00397346-f806-4ee1-973d-222590744178.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\01765036-e3bd-4b20-ba48-fee0dea8429b.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\018450aa-5285-42d4-8ed5-4e4aee06c0f3.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\018862e3-d5ae-49c8-b50f-4feaf43c0173.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\02066367-2067-4a2a-b09d-a4e8eb2b9197.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\02184174-aef1-4a94-a18f-dca2354c601f.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\0245340a-83e7-468b-91a1-e8bbe086c538.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\02528471-df55-4199-81e5-23f9ed08a6fd.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\026801ca-0a8a-4604-8d9a-5708011a488d.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\02986148-f6ff-4b7e-91df-8d85ae9d5313.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\03026562-d0ef-4c95-80be-f9f1aeed7d2b.jpg',
# ...

# %%
IMG_SIZE=256

# %%
testing_data = []

for img in filelist: 
    try:
        img_array = cv2.imread(img ,cv2.IMREAD_GRAYSCALE)  # convert to array
        new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize to normalize data size
        testing_data.append([new_array])  # add this to our training_data
        print(img)
    except Exception as e: 
        pass
# Out:
# C:/Users/nx1766/Desktop/Test31\0022303c-2d92-4f5a-8251-dbe878161100.jpg
# C:/Users/nx1766/Desktop/Test31\00397346-f806-4ee1-973d-222590744178.jpg
# C:/Users/nx1766/Desktop/Test31\01765036-e3bd-4b20-ba48-fee0dea8429b.jpg
# C:/Users/nx1766/Desktop/Test31\018450aa-5285-42d4-8ed5-4e4aee06c0f3.jpg
# C:/Users/nx1766/Desktop/Test31\018862e3-d5ae-49c8-b50f-4feaf43c0173.jpg
# C:/Users/nx1766/Desktop/Test31\02066367-2067-4a2a-b09d-a4e8eb2b9197.jpg
# C:/Users/nx1766/Desktop/Test31\02184174-aef1-4a94-a18f-dca2354c601f.jpg
# C:/Users/nx1766/Desktop/Test31\0245340a-83e7-468b-91a1-e8bbe086c538.jpg
# C:/Users/nx1766/Desktop/Test31\02528471-df55-4199-81e5-23f9ed08a6fd.jpg
# C:/Users/nx1766/Desktop/Test31\026801ca-0a8a-4604-8d9a-5708011a488d.jpg
# C:/Users/nx1766/Desktop/Test31\02986148-f6ff-4b7e-91df-8d85ae9d5313.jpg
# C:/Users/nx1766/Desktop/Test31\03026562-d0ef-4c95-80be-f9f1aeed7d2b.jpg
# C:/Users/nx1766/Desktop/Test31\03107745-ab0f-4490-a3de-25d938d0ad42.jpg
# ...

# %%
X=np.array(testing_data)
X=X/255

# %%
X[0]
# Out:
# array([[[0.32156863, 0.39607843, 0.80784314, ..., 0.43921569,
#          0.44313725, 0.44313725],
#         [0.35294118, 0.32941176, 0.79607843, ..., 0.43921569,
#          0.44313725, 0.44313725],
#         [0.37647059, 0.32156863, 0.88235294, ..., 0.44705882,
#          0.45098039, 0.44313725],
#         ...,
#         [0.62745098, 0.63921569, 0.6627451 , ..., 0.29803922,
#          0.21960784, 0.29411765],
#         [0.61960784, 0.65098039, 0.61960784, ..., 0.29803922,
#          0.27843137, 0.31372549],
#         [0.64705882, 0.6627451 , 0.63921569, ..., 0.29411765,
#          0.29019608, 0.27058824]]])

# %%
#import pickle

#pickle_out = open("C:/Users/nx1766/Desktop/test_pickle".pickle,"wb")
#pickle.dump(X, pickle_out)
#pickle_out.close()

# %%
#import pickle

#pickle_in = open("C:/Users/nx1766/Desktop/test_pickle","rb")
#X = pickle.load(pickle_in)

# %%
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
from tensorflow import keras
model4 = keras.models.load_model('C:/Users/nx1766/Desktop/Results_train31.h5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image

# %%
category=['Failure','Non Failure']

# %%
prediction = model4.predict(X,batch_size=32,steps=50,verbose=1)
# Out:
# 50/50 [==============================] - 1s 20ms/step

# %%
predicted_labels=[]
for img in prediction:
    predicted_labels.append(category[np.argmax(img)])

# %%
predicted_labels
# Out:
# ['Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Non Failure',
#  'Non Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Non Failure',
#  'Failure',
#  'Failure',
#  'Non Failure',
#  'Failure',
#  'Non Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Non Failure',
#  'Non Failure',
#  'Failure',
# ...

# %%
filelist
# Out:
# ['C:/Users/nx1766/Desktop/Test31\\0022303c-2d92-4f5a-8251-dbe878161100.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\00397346-f806-4ee1-973d-222590744178.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\01765036-e3bd-4b20-ba48-fee0dea8429b.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\018450aa-5285-42d4-8ed5-4e4aee06c0f3.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\018862e3-d5ae-49c8-b50f-4feaf43c0173.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\02066367-2067-4a2a-b09d-a4e8eb2b9197.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\02184174-aef1-4a94-a18f-dca2354c601f.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\0245340a-83e7-468b-91a1-e8bbe086c538.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\02528471-df55-4199-81e5-23f9ed08a6fd.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\026801ca-0a8a-4604-8d9a-5708011a488d.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\02986148-f6ff-4b7e-91df-8d85ae9d5313.jpg',
#  'C:/Users/nx1766/Desktop/Test31\\03026562-d0ef-4c95-80be-f9f1aeed7d2b.jpg',
# ...

# %%
cleaned_list=[]
for img in filelist:
    myfile=img.replace('C:/Users/nx1766/Desktop/split_raw image/Test31','')
    cleaned_list.append(myfile)

# %%
# import pandas as pd
import pandas as pd



# Calling DataFrame constructor after zipping
# both lists, with columns specified
df = pd.DataFrame(list(zip(cleaned_list,predicted_labels)),columns =['filename', 'classes'])

# %%
df
# Out:
#                                                filename  classes
# 0     C:/Users/nx1766/Desktop/Test31\0022303c-2d92-4...  Failure
# 1     C:/Users/nx1766/Desktop/Test31\00397346-f806-4...  Failure
# 2     C:/Users/nx1766/Desktop/Test31\01765036-e3bd-4...  Failure
# 3     C:/Users/nx1766/Desktop/Test31\018450aa-5285-4...  Failure
# 4     C:/Users/nx1766/Desktop/Test31\018862e3-d5ae-4...  Failure
# ...                                                 ...      ...
# 1595  C:/Users/nx1766/Desktop/Test31\eae09a24-ea10-4...  Failure
# 1596  C:/Users/nx1766/Desktop/Test31\eb033da0-3444-4...  Failure
# 1597  C:/Users/nx1766/Desktop/Test31\eb05ba17-7b42-4...  Failure
# 1598  C:/Users/nx1766/Desktop/Test31\eb20a420-6df8-4...  Failure
# 1599  C:/Users/nx1766/Desktop/Test31\eb2f5fe8-aa01-4...  Failure
#
# [1600 rows x 2 columns]

# %%
df.to_csv('final31.csv',index=False)
